# %% [markdown]
# <a href="https://colab.research.google.com/github/iemio/llms/blob/main/notebook_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata

# %%
google_api_key=userdata.get('GOOGLE_API_KEY')
groq_api_key=userdata.get('GROQ_API_KEY')

# %% [markdown]
# #Google Gemini

# %%
#!pip install google.generativeai
#Good for API based work
import google.generativeai as genai

genai.configure(api_key=google_api_key)
model = genai.GenerativeModel("gemini-1.5-flash")
response = model.generate_content("Explain how AI works")
print(response.text)
# Out:
# AI doesn't work in a single, unified way.  Instead, it's a broad field encompassing many different techniques and approaches. However, at a high level, most AI systems work by combining these key elements:
#
# **1. Data:**  AI systems learn from data. The more data they have, the better they typically perform. This data can be anything from images and text to sensor readings and financial transactions.  The quality and quantity of this data are crucial.
#
# **2. Algorithms:** These are sets of rules and statistical techniques that AI systems use to process and learn from data.  Different algorithms are suited for different tasks.  Some common examples include:
#
# * **Machine Learning (ML):**  This is a subfield of AI where systems learn patterns and make predictions from data without being explicitly programmed.  Different types of ML include:
#     * **Supervised Learning:** The algorithm learns from labeled data (e.g., images labeled as "cat" or "dog").
# ...

# %% [markdown]
# #Huggingface

# %%
# !pip install langchain_community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 42.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 52.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 413.0/413.0 kB 30.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.33
#     Uninstalling langchain-core-0.3.33:
#       Successfully uninstalled langchain-core-0.3.33
#   Attempting uninstall: langchain-text-splitters
#     Found existing installation: langchain-text-splitters 0.3.5
#     Uninstalling langchain-text-splitters-0.3.5:
#       Successfully uninstalled langchain-text-splitters-0.3.5
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.3.17
#     Uninstalling langchain-0.3.17:
#       Successfully uninstalled langchain-0.3.17
# ...

# %%
from langchain.llms import HuggingFacePipeline
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

model_id = "gpt2"
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(model_id)
pipe = pipeline("text-generation", model=model, tokenizer=tokenizer, max_new_tokens=100)
hf = HuggingFacePipeline(pipeline=pipe)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# Device set to use cpu
# ...

# %%
#!pip install --upgrade langchain langchain_core
from langchain_core.prompts import PromptTemplate

template = """Question: {question}

Answer: Let's think step by step."""
prompt = PromptTemplate.from_template(template)

chain = prompt | hf

question = "What is electroencephalography?"

print(chain.invoke({"question": question}))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Question: What is electroencephalography?
#
# Answer: Let's think step by step. The name is probably a bit vague. It uses an EEG, or EEG signal sensor. It's what they call a "brain stream signal" – that's the signal that tells somebody that something is going on. And a sensor doesn't measure the number of neurons because it detects that neurons are involved in some information that one might make more precise in terms of having more neurons in the brain. And that's where you would take a "brain stream signal."
#
# In that case the more neurons

# %% [markdown]
# #Ollama

# %%
# !pip install langchain_ollama

# %%
from langchain_ollama import OllamaLLM
DSmodel = OllamaLLM(model="llama3:latest", base_url="http://127.0.0.1:11434")

# %%
import requests

try:
    response = requests.get("http://localhost:11434/api/tags")
    print(response.json())
except requests.exceptions.ConnectionError as e:
    print(f"Connection error: {e}")
# Out:
# Connection error: HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/tags (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7c33c0200dd0>: Failed to establish a new connection: [Errno 111] Connection refused'))

# %%
from langchain_core.prompts import ChatPromptTemplate

# Prompt template
template = """Question: {question}
Answer: Let's keep it concise and actionable under 200 words"""
prompt = ChatPromptTemplate.from_template(template)
chain = prompt | DSmodel

chain.invoke({"question": "Please tell me about India in 100 words"})
# Out:
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/httpx/_transports/default.py in map_httpcore_exceptions()
#     100     try:
# --> 101         yield
#     102     except Exception as exc:
#
# /usr/local/lib/python3.11/dist-packages/httpx/_transports/default.py in handle_request(self, request)
#     249         with map_httpcore_exceptions():
# --> 250             resp = self._pool.handle_request(req)
#     251
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     255             self._close_connections(closing)
# --> 256             raise exc from None
#     257
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     235                     # Send the request on the assigned connection.
# ...

# %% [markdown]
# #Groq

# %%
# !pip install groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.9/121.9 kB 5.1 MB/s eta 0:00:00
# ...

# %%
import os

from groq import Groq

client = Groq(api_key=groq_api_key)

chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": "Please act like a mentor of communication and networking,"
            "help me write a small cold email. About me and context below:"
            "I am a data scientist based out of UK running a youtube channel Unfold data science"
            "where 100k people learn data science from me. "
            "My intent is to network and get connected with people in Ed tech industry"
            "to explore potential collaboration expecially in training domain. Please keep within 100 words",
        }
    ],
    model="llama-3.3-70b-versatile",
)

print(chat_completion.choices[0].message.content)
# Out:
# Here's a 100-word cold email:
#
# "Hi [Name],
# I'm [Your Name], a UK-based data scientist and founder of Unfold Data Science (100k+ YouTube subscribers). I'm eager to connect with EdTech professionals like yourself to explore collaboration opportunities in training. My channel focuses on making data science accessible. I'd love to discuss potential synergies and learn from your expertise. Would you be open to a brief call?
# Best, [Your Name]"
